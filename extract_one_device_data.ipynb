# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-1-d5df0069828e> in <module>
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.8/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      99 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#     100   """Mount your Google Drive at the specified mountpoint path."""
# --> 101   return _mount(
#     102       mountpoint,
#     103       force_remount=force_remount,
#
# /usr/local/lib/python3.8/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     122       'TBE_EPHEM_CREDS_ADDR'] if ephemeral else _os.environ['TBE_CREDS_ADDR']
#     123   if ephemeral:
# --> 124     _message.blocking_request(
# ...

# %% [markdown]
# # Import necessary libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline

import os
import glob
import json
from pathlib import Path

# %% [markdown]
# # **1. Import the main csv file sent by embedded team**

# %%
df=pd.read_csv("/content/drive/MyDrive/Senzmate/RCA/jsonoutput3.csv",  on_bad_lines='skip', index_col=0)#reading csv file
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df.head(5)
# Out:
#                         _id                             _class  \
# 0  61cf998d2d3b872d3baa528e  com.magma.core.data.entity.Sensor
# 1  61cf998d2d3b872d3baa528f  com.magma.core.data.entity.Sensor
# 2  61cf998d2d3b872d3baa5290  com.magma.core.data.entity.Sensor
# 3  61cf998d2d3b872d3baa5291  com.magma.core.data.entity.Sensor
# 4  61cf99902d3b872d3baa5297  com.magma.core.data.entity.Sensor
#
#           deviceId  number  code                      time          value  \
# 0  869170034808734       0     T  2022-01-01T00:00:13.521Z          21.14
# 1  869170034808734       1     H  2022-01-01T00:00:13.521Z         103.10
# 2  869170034808734       2  MEA4  2022-01-01T00:00:13.521Z  545.00/163.00
# 3  869170034808734       3     B  2022-01-01T00:00:13.521Z            266
# 4  869170034809062       0     T  2022-01-01T00:00:16.445Z          13.44
#
#                creationDate              modifiedDate
# 0  2022-01-01T00:00:13.522Z  2022-01-01T00:00:13.522Z
# ...

# %%
selcted_device_ids = list(df.deviceId.values[0:1])
selcted_device_ids
# Out:
# ['869170034808734']

# %%
df2 = df[df["deviceId"].isin(selcted_device_ids)]

# %%
df2.head(5)
# Out:
#                           _id                             _class  \
# 0    61cf998d2d3b872d3baa528e  com.magma.core.data.entity.Sensor
# 1    61cf998d2d3b872d3baa528f  com.magma.core.data.entity.Sensor
# 2    61cf998d2d3b872d3baa5290  com.magma.core.data.entity.Sensor
# 3    61cf998d2d3b872d3baa5291  com.magma.core.data.entity.Sensor
# 282  61cf9bc72d3b872d3baa54fa  com.magma.core.data.entity.Sensor
#
#             deviceId  number  code                      time          value  \
# 0    869170034808734       0     T  2022-01-01T00:00:13.521Z          21.14
# 1    869170034808734       1     H  2022-01-01T00:00:13.521Z         103.10
# 2    869170034808734       2  MEA4  2022-01-01T00:00:13.521Z  545.00/163.00
# 3    869170034808734       3     B  2022-01-01T00:00:13.521Z            266
# 282  869170034808734       0     T  2022-01-01T00:09:43.709Z          21.08
#
#                  creationDate              modifiedDate
# 0    2022-01-01T00:00:13.522Z  2022-01-01T00:00:13.522Z
# ...

# %%
df2.to_csv('/content/drive/MyDrive/Senzmate/RCA/jsonoutput3_one_device.csv', index=False)

# %%
df3=pd.read_csv("/content/drive/MyDrive/Senzmate/RCA/jsonoutput3_one_device.csv",  on_bad_lines='skip')

# %%
df3.head(5)
# Out:
#                         _id                             _class  \
# 0  61cf998d2d3b872d3baa528e  com.magma.core.data.entity.Sensor
# 1  61cf998d2d3b872d3baa528f  com.magma.core.data.entity.Sensor
# 2  61cf998d2d3b872d3baa5290  com.magma.core.data.entity.Sensor
# 3  61cf998d2d3b872d3baa5291  com.magma.core.data.entity.Sensor
# 4  61cf9bc72d3b872d3baa54fa  com.magma.core.data.entity.Sensor
#
#           deviceId  number  code                      time          value  \
# 0  869170034808734       0     T  2022-01-01T00:00:13.521Z          21.14
# 1  869170034808734       1     H  2022-01-01T00:00:13.521Z         103.10
# 2  869170034808734       2  MEA4  2022-01-01T00:00:13.521Z  545.00/163.00
# 3  869170034808734       3     B  2022-01-01T00:00:13.521Z            266
# 4  869170034808734       0     T  2022-01-01T00:09:43.709Z          21.08
#
#                creationDate              modifiedDate
# 0  2022-01-01T00:00:13.522Z  2022-01-01T00:00:13.522Z
# ...
