# %% [markdown]
# **Sync With Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Import necessary libraries

# %%
import numpy as np
import pandas as pd

import dask.dataframe as dd
import dask.array as da
import dask.bag as db

# %% [markdown]
# # **1. Import the main csv file sent by embedded team**

# %%
# ddf = dd.read_csv("/content/drive/MyDrive/Senzmate/RCA/jsonoutput3.csv", blocksize=25e6) # - deviceId ValueError("invalid literal for int() with base 10: 'peercore-F'")

ddf = dd.read_csv("/content/drive/MyDrive/Senzmate/RCA/jsonoutput3.csv", dtype={'deviceId': 'object'})

# %%
ddf.head()
# Out:
#    Unnamed: 0                       _id                             _class  \
# 0           0  61cf998d2d3b872d3baa528e  com.magma.core.data.entity.Sensor
# 1           1  61cf998d2d3b872d3baa528f  com.magma.core.data.entity.Sensor
# 2           2  61cf998d2d3b872d3baa5290  com.magma.core.data.entity.Sensor
# 3           3  61cf998d2d3b872d3baa5291  com.magma.core.data.entity.Sensor
# 4           4  61cf99902d3b872d3baa5297  com.magma.core.data.entity.Sensor
#
#           deviceId  number  code                      time          value  \
# 0  869170034808734       0     T  2022-01-01T00:00:13.521Z          21.14
# 1  869170034808734       1     H  2022-01-01T00:00:13.521Z         103.10
# 2  869170034808734       2  MEA4  2022-01-01T00:00:13.521Z  545.00/163.00
# 3  869170034808734       3     B  2022-01-01T00:00:13.521Z            266
# 4  869170034809062       0     T  2022-01-01T00:00:16.445Z          13.44
#
#                creationDate              modifiedDate
# 0  2022-01-01T00:00:13.522Z  2022-01-01T00:00:13.522Z
# 1  2022-01-01T00:00:13.523Z  2022-01-01T00:00:13.523Z
# 2  2022-01-01T00:00:13.524Z  2022-01-01T00:00:13.524Z
# 3  2022-01-01T00:00:13.524Z  2022-01-01T00:00:13.524Z
# 4  2022-01-01T00:00:16.445Z  2022-01-01T00:00:16.445Z

# %% [markdown]
# # **Recreating a CSV by adding error flags directly to main csv**

# %% [markdown]
# Here didn't group the devices. If the dataponit is an error then the error flag i 1, otherwise 0.(If the datapoint is outlier => outlier flag =1)

# %% [markdown]
# **remove unwanted column**

# %%
ddf = ddf.drop(columns=['Unnamed: 0', '_id', '_class', 'number', 'creationDate', 'modifiedDate'])
ddf.head()
# Out:
#           deviceId  code                      time          value
# 0  869170034808734     T  2022-01-01T00:00:13.521Z          21.14
# 1  869170034808734     H  2022-01-01T00:00:13.521Z         103.10
# 2  869170034808734  MEA4  2022-01-01T00:00:13.521Z  545.00/163.00
# 3  869170034808734     B  2022-01-01T00:00:13.521Z            266
# 4  869170034809062     T  2022-01-01T00:00:16.445Z          13.44

# %% [markdown]
# **Remove unwanted sensor data**

# %%
needed_values = ["B", "IT", "LIA1", "H", "IRO", "T", "ST", "SS"]
ddf2 = ddf.loc[ddf['code'].isin(needed_values)].reset_index(drop=True)

# %%
ddf2.head()
# Out:
#           deviceId code                      time   value
# 0  869170034808734    T  2022-01-01T00:00:13.521Z   21.14
# 1  869170034808734    H  2022-01-01T00:00:13.521Z  103.10
# 2  869170034808734    B  2022-01-01T00:00:13.521Z     266
# 3  869170034809062    T  2022-01-01T00:00:16.445Z   13.44
# 4  869170034809062    H  2022-01-01T00:00:16.445Z   98.55

# %% [markdown]
# **outlier detection**

# %%
VALUES_RANGE = {'B': {"min": 260, "max": 314},
                'IT': {"min": -55, "max": 125},
                'LIA1': {"min": 0, "max": 65535},
                'H': {"min": 0, "max": 110},
                'IRO': {"min": 0, "max": 200},
                'T': {"min": -40, "max": 125},
                'ST': {"min": -55, "max": 125},
                'SS': {"min": 2, "max": 30},
                }
def detect_outlier(row):
  try:
    if VALUES_RANGE[row.code]['min'] <= float(row.value) <= VALUES_RANGE[row.code]['max']:
      return 0
  except:
    pass
  return 1

# %%
ddf2['outlier_data_flag'] = ddf2.apply(lambda row: detect_outlier(row), axis=1, meta=pd.Series(dtype="int32"))

# %%
ddf2.head(5)
# Out:
#           deviceId code                      time   value  outlier_data_flag
# 0  869170034808734    T  2022-01-01T00:00:13.521Z   21.14                  0
# 1  869170034808734    H  2022-01-01T00:00:13.521Z  103.10                  0
# 2  869170034808734    B  2022-01-01T00:00:13.521Z     266                  0
# 3  869170034809062    T  2022-01-01T00:00:16.445Z   13.44                  0
# 4  869170034809062    H  2022-01-01T00:00:16.445Z   98.55                  0

# %%
ddf2.tail(5)
# Out:
#                 deviceId code                      time   value  \
# 283293  8691700348087260    T  2022-07-01T00:00:00.000Z   18.15
# 283294  8691700348087260    H  2022-07-01T00:00:00.000Z  101.55
# 283295  8691700348087260    B  2022-07-01T00:00:00.000Z     273
# 283296  8691700348087260   IT  2022-07-01T00:00:00.000Z      43
# 283297  8691700348087260   ST  2022-07-01T00:00:00.000Z      00
#
#         outlier_data_flag
# 283293                  0
# 283294                  0
# 283295                  0
# 283296                  0
# 283297                  0

# %% [markdown]
# **high volume check**

# %%
ddf2['high_volume'] = 1
ddf2.groupby(['deviceId','code', 'time']).high_volume.count().reset_index()
# Out:
# Dask DataFrame Structure:
#               deviceId    code    time high_volume
# npartitions=1
#                 object  object  object       int64
#                    ...     ...     ...         ...
# Dask Name: reset_index, 216 tasks

# %%
ddf2.head(5)
# Out:
#           deviceId code                      time   value  outlier_data_flag  \
# 0  869170034808734    T  2022-01-01T00:00:13.521Z   21.14                  0
# 1  869170034808734    H  2022-01-01T00:00:13.521Z  103.10                  0
# 2  869170034808734    B  2022-01-01T00:00:13.521Z     266                  0
# 3  869170034809062    T  2022-01-01T00:00:16.445Z   13.44                  0
# 4  869170034809062    H  2022-01-01T00:00:16.445Z   98.55                  0
#
#    high_volume
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1

# %%
# ddf2.to_csv('/content/drive/MyDrive/Senzmate/RCA/result_1/export-*.csv', index=False)

# %%
ddf2['high_volume_flag'] = ddf2.apply(lambda row: 1 if row.high_volume > 1 else 0, axis=1, meta=pd.Series(dtype="int32"))
ddf2.head(5)
# Out:
#           deviceId code                      time   value  outlier_data_flag  \
# 0  869170034808734    T  2022-01-01T00:00:13.521Z   21.14                  0
# 1  869170034808734    H  2022-01-01T00:00:13.521Z  103.10                  0
# 2  869170034808734    B  2022-01-01T00:00:13.521Z     266                  0
# 3  869170034809062    T  2022-01-01T00:00:16.445Z   13.44                  0
# 4  869170034809062    H  2022-01-01T00:00:16.445Z   98.55                  0
#
#    high_volume  high_volume_flag
# 0            1                 0
# 1            1                 0
# 2            1                 0
# 3            1                 0
# 4            1                 0

# %%
# ddf2.to_csv('/content/drive/MyDrive/Senzmate/RCA/result_2/export-*.csv')

# %%
# ddf2['high_volume'] = ddf2.groupby(['deviceId', 'code', 'time'])['value'].transform('size')
# ddf2['high_volume_flag'] = ddf2.apply(lambda row: 1 if row.high_volume > 1 else 0, axis=1, meta=pd.Series(dtype="int64"))

# %%
ddf2.head(5)
# Out:
#           deviceId code                      time   value  outlier_data_flag  \
# 0  869170034808734    T  2022-01-01T00:00:13.521Z   21.14                  0
# 1  869170034808734    H  2022-01-01T00:00:13.521Z  103.10                  0
# 2  869170034808734    B  2022-01-01T00:00:13.521Z     266                  0
# 3  869170034809062    T  2022-01-01T00:00:16.445Z   13.44                  0
# 4  869170034809062    H  2022-01-01T00:00:16.445Z   98.55                  0
#
#    high_volume  high_volume_flag
# 0            1                 0
# 1            1                 0
# 2            1                 0
# 3            1                 0
# 4            1                 0

# %%
ddf2['miss_data_flag'] = 0
ddf2.head(0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ddccdbccb00b> in <module>
# ----> 1 ddf2['miss_data_flag'] = 0
#       2 ddf2.head(0)
#
# NameError: name 'ddf2' is not defined

# %%
grp_deviceId_time = ddf2.groupby(['deviceId', 'time'])

# %%
# ddf2.groupby(['deviceId', 'time']).apply(func)

# %%
l1 = []
def my_function(df):
  captured_values = df['code'].values
  res = [*set(captured_values)]
  for sensor in needed_values:
    if sensor not in res:
      new_row = {'deviceId':df['deviceId'].iat[0], 'code':sensor, 'time':df['time'].iat[0], 'value':0, 'outlier_data_flag':0, 'high_volume':0, 'high_volume_flag':0, 'miss_data_flag': 1}
      new_df = pd.DataFrame.from_dict(new_row)

      df.append(new_df)
  l1.append(df)
  return df

# %%
meta_df = pd.DataFrame(columns=['outlier_data_flag', 'high_volume', 'high_volume_flag', 'miss_data_flag'])

ddf2.groupby(['deviceId', 'time']).apply(my_function, meta=meta_df).compute()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-a37d36205dfb> in <module>
#       1 meta_df = pd.DataFrame(columns=['outlier_data_flag', 'high_volume', 'high_volume_flag', 'miss_data_flag'])
#       2
# ----> 3 ddf2.groupby(['deviceId', 'time']).apply(my_function, meta=meta_df).compute()
#
# /usr/local/lib/python3.8/dist-packages/dask/base.py in compute(self, **kwargs)
#     288         dask.base.compute
#     289         """
# --> 290         (result,) = compute(self, traverse=False, **kwargs)
#     291         return result
#     292
#
# /usr/local/lib/python3.8/dist-packages/dask/base.py in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     571         postcomputes.append(x.__dask_postcompute__())
#     572
# --> 573     results = schedule(dsk, keys, **kwargs)
#     574     return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#     575
#
# /usr/local/lib/python3.8/dist-packages/dask/threaded.py in get(dsk, result, cache, num_workers, pool, **kwargs)
#      79             pool = MultiprocessingPoolExecutor(pool)
#      80
# ---> 81     results = get_async(
#      82         pool.submit,
#      83         pool._max_workers,
#
# /usr/local/lib/python3.8/dist-packages/dask/local.py in get_async(submit, num_workers, dsk, result, cache, get_id, rerun_exceptions_locally, pack_exception, raise_exception, callbacks, dumps, loads, chunksize, **kwargs)
#     504                             _execute_task(task, data)  # Re-execute locally
#     505                         else:
# --> 506                             raise_exception(exc, tb)
#     507                     res, worker_id = loads(res_info)
#     508                     state["cache"][key] = res
#
# /usr/local/lib/python3.8/dist-packages/dask/local.py in reraise(exc, tb)
#     312     if exc.__traceback__ is not tb:
#     313         raise exc.with_traceback(tb)
# --> 314     raise exc
#     315
#     316
#
# /usr/local/lib/python3.8/dist-packages/dask/local.py in execute_task(key, task_info, dumps, loads, get_id, pack_exception)
#     217     try:
#     218         task, data = loads(task_info)
# --> 219         result = _execute_task(task, data)
#     220         id = get_id()
#     221         result = dumps((result, id))
#
# /usr/local/lib/python3.8/dist-packages/dask/core.py in _execute_task(arg, cache, dsk)
#     117         # temporaries by their reference count and can execute certain
#     118         # operations in-place.
# --> 119         return func(*(_execute_task(a, cache) for a in args))
#     120     elif not ishashable(arg):
#     121         return arg
#
# /usr/local/lib/python3.8/dist-packages/dask/optimization.py in __call__(self, *args)
#     967         if not len(args) == len(self.inkeys):
#     968             raise ValueError("Expected %d args, got %d" % (len(self.inkeys), len(args)))
# --> 969         return core.get(self.dsk, self.outkey, dict(zip(self.inkeys, args)))
#     970
#     971     def __reduce__(self):
#
# /usr/local/lib/python3.8/dist-packages/dask/core.py in get(dsk, out, cache)
#     147     for key in toposort(dsk):
#     148         task = dsk[key]
# --> 149         result = _execute_task(task, cache)
#     150         cache[key] = result
#     151     result = _execute_task(out, cache)
#
# /usr/local/lib/python3.8/dist-packages/dask/core.py in _execute_task(arg, cache, dsk)
#     117         # temporaries by their reference count and can execute certain
#     118         # operations in-place.
# --> 119         return func(*(_execute_task(a, cache) for a in args))
#     120     elif not ishashable(arg):
#     121         return arg
#
# /usr/local/lib/python3.8/dist-packages/dask/utils.py in apply(func, args, kwargs)
#      37 def apply(func, args, kwargs=None):
#      38     if kwargs:
# ---> 39         return func(*args, **kwargs)
#      40     else:
#      41         return func(*args)
#
# /usr/local/lib/python3.8/dist-packages/dask/dataframe/core.py in apply_and_enforce(*args, **kwargs)
#    6257     func = kwargs.pop("_func")
#    6258     meta = kwargs.pop("_meta")
# -> 6259     df = func(*args, **kwargs)
#    6260     if is_dataframe_like(df) or is_series_like(df) or is_index_like(df):
#    6261         if not len(df):
#
# /usr/local/lib/python3.8/dist-packages/dask/dataframe/groupby.py in _groupby_slice_apply(df, grouper, key, func, group_keys, dropna, observed, *args, **kwargs)
#     168     if key:
#     169         g = g[key]
# --> 170     return g.apply(func, *args, **kwargs)
#     171
#     172
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/groupby/groupby.py in apply(self, func, *args, **kwargs)
#    1273         with option_context("mode.chained_assignment", None):
#    1274             try:
# -> 1275                 result = self._python_apply_general(f, self._selected_obj)
#    1276             except TypeError:
#    1277                 # gh-20949
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/groupby/groupby.py in _python_apply_general(self, f, data)
#    1307             data after applying f
#    1308         """
# -> 1309         keys, values, mutated = self.grouper.apply(f, data, self.axis)
#    1310
#    1311         return self._wrap_applied_output(
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/groupby/ops.py in apply(self, f, data, axis)
#     813             try:
#     814                 sdata = splitter.sorted_data
# --> 815                 result_values, mutated = splitter.fast_apply(f, sdata, group_keys)
#     816
#     817             except IndexError:
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/groupby/ops.py in fast_apply(self, f, sdata, names)
#    1358         # must return keys::list, values::list, mutated::bool
#    1359         starts, ends = lib.generate_slices(self.slabels, self.ngroups)
# -> 1360         return libreduction.apply_frame_axis0(sdata, f, names, starts, ends)
#    1361
#    1362     def _chop(self, sdata: DataFrame, slice_obj: slice) -> DataFrame:
#
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/reduction.pyx in pandas._libs.reduction.apply_frame_axis0()
#
# <ipython-input-19-edbd41a7a63e> in my_function(df)
#       6     if sensor not in res:
#       7       new_row = {'deviceId':df['deviceId'].iat[0], 'code':sensor, 'time':df['time'].iat[0], 'value':0, 'outlier_data_flag':0, 'high_volume':0, 'high_volume_flag':0, 'miss_data_flag': 1}
# ----> 8       new_df = pd.DataFrame.from_dict(new_row)
#       9
#      10       df.append(new_df)
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in from_dict(cls, data, orient, dtype, columns)
#    1591             raise ValueError("only recognize index or columns for orient")
#    1592
# -> 1593         return cls(data, index=index, columns=columns, dtype=dtype)
#    1594
#    1595     def to_numpy(
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     612         elif isinstance(data, dict):
#     613             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 614             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     615         elif isinstance(data, ma.MaskedArray):
#     616             import numpy.ma.mrecords as mrecords
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     462         # TODO: can we get rid of the dt64tz special case above?
#     463
# --> 464     return arrays_to_mgr(
#     465         arrays, data_names, index, columns, dtype=dtype, typ=typ, consolidate=copy
#     466     )
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity, typ, consolidate)
#     117         # figure out the index, if necessary
#     118         if index is None:
# --> 119             index = _extract_index(arrays)
#     120         else:
#     121             index = ensure_index(index)
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/construction.py in _extract_index(data)
#     623
#     624         if not indexes and not raw_lengths:
# --> 625             raise ValueError("If using all scalar values, you must pass an index")
#     626
#     627         if have_series:
#
# ValueError: If using all scalar values, you must pass an index

# %%
result = dd.concat(l1)

# %%
from joblib import Parallel, delayed
import multiprocessing

needed_values = ["B", "IT", "LIA1", "H", "IRO", "T", "ST", "SS"]

def tmpFunc(df):
  captured_values = ddf['code'].values
  res = [*set(captured_values)]
  for sensor in needed_values:
    if sensor not in res:
      new_row = {'deviceId':id[0], 'code':sensor, 'time':id[1], 'value':0, 'outlier_data_flag':0, 'high_volume':0, 'high_volume_flag':0, 'miss_data_flag': 1}
      new_df = pd.DataFrame.from_dict(new_row)

      df.append(new_df)
  return df

def applyParallel(dfGrouped, func):
    retLst = Parallel(n_jobs=multiprocessing.cpu_count())(delayed(func)(group) for name, group in dfGrouped)
    return pd.concat(retLst)

result = ddf2.groupby(['deviceId', 'time']).apply(tmpFunc)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/dask/dataframe/utils.py in raise_on_meta_error(funcname, udf)
#     176     try:
# --> 177         yield
#     178     except Exception as e:
#
# /usr/local/lib/python3.8/dist-packages/dask/dataframe/groupby.py in apply(self, func, *args, **kwargs)
#    1699                 meta_args, meta_kwargs = _extract_meta((args, kwargs), nonempty=True)
# -> 1700                 meta = self._meta_nonempty.apply(func, *meta_args, **meta_kwargs)
#    1701
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/groupby/groupby.py in apply(self, func, *args, **kwargs)
#    1274             try:
# -> 1275                 result = self._python_apply_general(f, self._selected_obj)
#    1276             except TypeError:
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/groupby/groupby.py in _python_apply_general(self, f, data)
#    1308         """
# -> 1309         keys, values, mutated = self.grouper.apply(f, data, self.axis)
#    1310
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/groupby/ops.py in apply(self, f, data, axis)
#     814                 sdata = splitter.sorted_data
# --> 815                 result_values, mutated = splitter.fast_apply(f, sdata, group_keys)
#     816
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/groupby/ops.py in fast_apply(self, f, sdata, names)
#    1359         starts, ends = lib.generate_slices(self.slabels, self.ngroups)
# -> 1360         return libreduction.apply_frame_axis0(sdata, f, names, starts, ends)
#    1361
#
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/reduction.pyx in pandas._libs.reduction.apply_frame_axis0()
#
# <ipython-input-43-4f9825d2fc8a> in tmpFunc(df)
#       7   captured_values = ddf['code'].values
# ----> 8   res = [*set(captured_values)]
#       9   for sensor in needed_values:
#
# /usr/local/lib/python3.8/dist-packages/dask/array/core.py in __iter__(self)
#    1619     def __iter__(self):
# -> 1620         for i in range(len(self)):
#    1621             yield self[i]
#
# /usr/local/lib/python3.8/dist-packages/dask/array/core.py in __len__(self)
#    1490             )
# -> 1491             raise ValueError(msg)
#    1492         return int(sum(self.chunks[0]))
#
# ValueError: Cannot call len() on object with unknown chunk size.
#
# A possible solution: https://docs.dask.org/en/latest/array-chunks.html#unknown-chunks
# Summary: to compute chunks sizes, use
#
#    x.compute_chunk_sizes()  # for Dask Array `x`
#    ddf.to_dask_array(lengths=True)  # for Dask DataFrame `ddf`
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-4f9825d2fc8a> in <module>
#      19     return pd.concat(retLst)
#      20
# ---> 21 result = ddf2.groupby(['deviceId', 'time']).apply(tmpFunc)
#
# /usr/local/lib/python3.8/dist-packages/dask/dataframe/groupby.py in apply(self, func, *args, **kwargs)
#    1698             with raise_on_meta_error(f"groupby.apply({funcname(func)})", udf=True):
#    1699                 meta_args, meta_kwargs = _extract_meta((args, kwargs), nonempty=True)
# -> 1700                 meta = self._meta_nonempty.apply(func, *meta_args, **meta_kwargs)
#    1701
#    1702             msg = (
#
# /usr/lib/python3.8/contextlib.py in __exit__(self, type, value, traceback)
#     129                 value = type()
#     130             try:
# --> 131                 self.gen.throw(type, value, traceback)
#     132             except StopIteration as exc:
#     133                 # Suppress StopIteration *unless* it's the same exception that
#
# /usr/local/lib/python3.8/dist-packages/dask/dataframe/utils.py in raise_on_meta_error(funcname, udf)
#     196         )
#     197         msg = msg.format(f" in `{funcname}`" if funcname else "", repr(e), tb)
# --> 198         raise ValueError(msg) from e
#     199
#     200
#
# ValueError: Metadata inference failed in `groupby.apply(tmpFunc)`.
#
# You have supplied a custom function and Dask is unable to
# determine the type of output that that function returns.
#
# To resolve this please provide a meta= keyword.
# The docstring of the Dask function you ran should have more information.
#
# Original error is below:
# ------------------------
# ValueError('Cannot call len() on object with unknown chunk size.\n\nA possible solution: https://docs.dask.org/en/latest/array-chunks.html#unknown-chunks\nSummary: to compute chunks sizes, use\n\n   x.compute_chunk_sizes()  # for Dask Array `x`\n   ddf.to_dask_array(lengths=True)  # for Dask DataFrame `ddf`')
#
# Traceback:
# ---------
#   File "/usr/local/lib/python3.8/dist-packages/dask/dataframe/utils.py", line 177, in raise_on_meta_error
#     yield
#   File "/usr/local/lib/python3.8/dist-packages/dask/dataframe/groupby.py", line 1700, in apply
#     meta = self._meta_nonempty.apply(func, *meta_args, **meta_kwargs)
#   File "/usr/local/lib/python3.8/dist-packages/pandas/core/groupby/groupby.py", line 1275, in apply
#     result = self._python_apply_general(f, self._selected_obj)
#   File "/usr/local/lib/python3.8/dist-packages/pandas/core/groupby/groupby.py", line 1309, in _python_apply_general
#     keys, values, mutated = self.grouper.apply(f, data, self.axis)
#   File "/usr/local/lib/python3.8/dist-packages/pandas/core/groupby/ops.py", line 815, in apply
#     result_values, mutated = splitter.fast_apply(f, sdata, group_keys)
#   File "/usr/local/lib/python3.8/dist-packages/pandas/core/groupby/ops.py", line 1360, in fast_apply
#     return libreduction.apply_frame_axis0(sdata, f, names, starts, ends)
#   File "pandas/_libs/reduction.pyx", line 381, in pandas._libs.reduction.apply_frame_axis0
#   File "<ipython-input-43-4f9825d2fc8a>", line 8, in tmpFunc
#     res = [*set(captured_values)]
#   File "/usr/local/lib/python3.8/dist-packages/dask/array/core.py", line 1620, in __iter__
#     for i in range(len(self)):
#   File "/usr/local/lib/python3.8/dist-packages/dask/array/core.py", line 1491, in __len__
#     raise ValueError(msg)

# %%
needed_values = ["B", "IT", "LIA1", "H", "IRO", "T", "ST", "SS"]
frames = []
i = 0
for id, ddf in grp_deviceId_time:
  if i > 3:
    break
  captured_values = ddf['code'].values
  res = [*set(captured_values)]
  for sensor in needed_values:
    if sensor not in res:
      new_row = {'deviceId':id[0], 'code':sensor, 'time':id[1], 'value':0, 'outlier_data_flag':0, 'high_volume':0, 'high_volume_flag':0, 'miss_data_flag': 1}
      new_df = pd.DataFrame.from_dict(new_row)

      ddf.append(new_df)
  i = i + 1
  frames.append(ddf)
  # result = pd.concat([result, df], axis=1)
result = dd.concat(frames)
result['miss_data_flag'] = result['miss_data_flag'].fillna(0).astype('Int32')
result.head()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-42-e97834a333e7> in <module>
#       2 frames = []
#       3 i = 0
# ----> 4 for id, ddf in grp_deviceId_time:
#       5   if i > 3:
#       6     break
#
# /usr/local/lib/python3.8/dist-packages/dask/dataframe/groupby.py in __iter__(self)
#    1126
#    1127     def __iter__(self):
# -> 1128         raise NotImplementedError(
#    1129             "Iteration of DataFrameGroupBy objects requires computing the groups which "
#    1130             "may be slow. You probably want to use 'apply' to execute a function for "
#
# NotImplementedError: Iteration of DataFrameGroupBy objects requires computing the groups which may be slow. You probably want to use 'apply' to execute a function for all the columns. To access individual groups, use 'get_group'. To list all the group names, use 'df[<group column>].unique().compute()'.

# %%
result.to_csv('/content/drive/MyDrive/RCA/result_20.csv')

# %%
needed_values = ["B", "IT", "LIA1", "H", "IRO", "T", "ST", "SS"]
new_index = Index(needed_values, name="code")
# result = pd.DataFrame()
frames = []
for id,df in grp_deviceId_time:
  df['miss_data_flag'] = 0
  df.set_index("code").reindex(new_index).reset_index()
  df['deviceId'] = df['deviceId'].fillna(id[0])
  df['time'] = df['time'].fillna(id[1])
  df['miss_data_flag'] = df['miss_data_flag'].fillna(0).astype('Int32')

  frames.append(df)

result = pd.concat(frames, axis=1)
result['miss_data_flag'] = result['miss_data_flag'].fillna(0).astype('Int32')
result.head(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-4612f7fa87bc> in <module>
#       1 needed_values = ["B", "IT", "LIA1", "H", "IRO", "T", "ST", "SS"]
# ----> 2 new_index = Index(needed_values, name="code")
#       3 # result = pd.DataFrame()
#       4 frames = []
#       5 for id,df in grp_deviceId_time:
#
# NameError: name 'Index' is not defined

# %%
result.to_csv('/content/drive/MyDrive/Senzmate/RCA/result_2.csv')

# %% [markdown]
# # **=====> creating datasets for each devices and add error flag columnsin table and create json file for each devices contain their errors**

# %% [markdown]
# # **2. Group the dataframe for each device**

# %% [markdown]
# *   "deviceId" is used to group

# %%
grp_deviceId = df.groupby('deviceId')

# %%
VALUES_RANGE = {'B': {"min": 260, "max": 314},
                'IT': {"min": -55, "max": 125},
                'LIA1': {"min": 0, "max": 65535},
                'H': {"min": 0, "max": 110},
                'IRO': {"min": 0, "max": 200},
                'T': {"min": -40, "max": 125},
                'ST': {"min": -55, "max": 125},
                'SS': {"min": 2, "max": 30},
                }
def detect_outlier(value_array, sensor_name):
  min_value = VALUES_RANGE[sensor_name]['min']
  max_value = VALUES_RANGE[sensor_name]['max']
  try:
    value_array_float = value_array.astype(np.float)
    detect = np.any((value_array_float <= max_value)|(value_array_float >= min_value ))
    if detect: 
      return 0
  except:
    pass
    # print("sensor_name ", sensor_name, " value_array ", value_array)
  return 1

# %% [markdown]
# # **3. Create new dataframe for each devices with error flags**

# %%
needed_values = ["B", "IT", "LIA1", "H", "IRO", "T", "ST", "SS"]


for id,df in grp_deviceId:
  df = df[['time','code','value']]
  df_columns = list(df.columns)
  df = df.groupby(['time', 'code'])['value'].apply(list).reset_index()        # group the values for a same instant of a sensor(Find missing and high volume flags)
  pivot_df = df.reset_index().pivot(values='value', index='time', columns='code') # unmelt the sensor category

  for column in pivot_df.columns:
    if column in needed_values:
      data_miss_flag = '{}_data_miss_flag'.format(column)
      high_volume = '{}_high_volumn'.format(column)
      high_volume_flag = '{}_high_volumn_flag'.format(column)

      outlier_flag = '{}_outlier_flag'.format(column)

      pivot_df[data_miss_flag] = pivot_df.apply(lambda row: 1 if np.array(pd.isnull(row[column])).any() else 0, axis=1)
      pivot_df[high_volume] = pivot_df.apply(lambda row: len(row[column]) if row[data_miss_flag] == 0 else 0, axis=1)
      pivot_df[high_volume_flag] = pivot_df.apply(lambda row: 1 if row[high_volume] > 1 else 0, axis=1)
      pivot_df[outlier_flag] = pivot_df.apply(lambda row: detect_outlier(np.array(row[column]), column) if row[data_miss_flag] == 0 else 0, axis=1)

      pivot_df = pivot_df.drop(high_volume, axis=1)
    else:
      pivot_df = pivot_df.drop(column, axis=1)

  pivot_df.to_csv('/content/drive/MyDrive/Senzmate/RCA/Analyzed_dataframes_for_each_devices/{}.csv'.format(id))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %%
{'CN', 'SS', 'CS', 'RF', 'N', 'B', 'MEA3', 'X', 'M', 'H', 'MEA2', 'ST', 'WD', 'P', 'WS', 'LIA1', 'IT', 'MEA4', 'T', 'MEA', 'CT', 'Y', 'IRO', 'MEA1'}

# %% [markdown]
# # **4. Create json files for each device to record its faults**

# %%
path = '/content/drive/MyDrive/Senzmate/RCA/Analyzed_dataframes_for_each_devices/'
os.chdir(path)
csv_files = glob.glob('*.csv')
print(csv_files)
# Out:
# ['0033201246.csv', '0033208845.csv', '1031324235.csv', '1032721006.csv', '1033201220.csv', '1033915738.csv', '1036217273.csv', '1136917432.csv', '2030564842.csv', '1036917432.csv', '1044444444.csv', '2035371870.csv', '2038599606.csv', '29032431423.csv', '3032721006.csv', '3601225.csv', '4031324235.csv', '4035663649.csv', '64034160230.csv', '62035787778.csv', '42220711.csv', '67023401394.csv', '56030210204.csv', '67023401626.csv', '67023402079.csv', '70033201204.csv', '70033894495.csv', '70033894792.csv', '7023401402.csv', '70034808528.csv', '70034810839.csv', '7028360827.csv', '72035398465.csv', '74032175024.csv', '74033087103.csv', '861311002933124.csv', '861311003410015.csv', '861311003410023.csv', '861311003411179.csv', '861311003412789.csv', '861311003414587.csv', '861311003420956.csv', '861311003609699.csv', '861311004363833.csv', '8635840320262950.csv', '8643690373854100.csv', '865067023394920.csv', '8647640306331980.csv', '8650670233952730.csv', '865067023395711.csv', '865067023395760.csv', '8650670233957600.csv', '865067023398384.csv', '865067023398939.csv', '865067023399523.csv', '8650670234013940.csv', '865067023401402.csv', '8650670234016260.csv', '8650670234020790.csv', '865067023402772.csv', '865067027391039.csv', '865067027391260.csv', '865067027394371.csv', '865067027394751.csv', '865067027394801.csv', '865067027394900.csv', '865067027395188.csv', '865067027394918.csv', '865067027395410.csv', '865067027395501.csv', '865067027395642.csv', '865067027395592.csv', '865067027396640.csv', '865067028355918.csv', '865067027399354.csv', '865067027399362.csv', '865067028360538.csv', '8656910315971310.csv', '8659920301288150.csv', '8662620305648420.csv', '8660290362172730.csv', '8662620365560240.csv', '8678560302102040.csv', '869170031224224.csv', '869170031225916.csv', '869170031226492.csv', '8691700332011960.csv', '869170033201220.csv', '8691700332012040.csv', '869170033201246.csv', '8691700332012790.csv', '869170033201378.csv', '869170033208787.csv', '869170033208803.csv', '869170033208845.csv', '8691700338942890.csv', '869170033894388.csv', '869170033894412.csv', '869170033894479.csv', '869170033894453.csv', '869170033894487.csv', '8691700338944950.csv', '869170033894503.csv', '869170033894537.csv', '8691700338947920.csv', '869170033894826.csv', '869170033897167.csv', '869170033897092.csv', '869170033897183.csv', '869170033897324.csv', '8691700338971831.csv', '869170033903866.csv', '869170033913501.csv', '869170033915407.csv', '869170033915431.csv', '869170033915506.csv', '869170033915704.csv', '869170033915720.csv', '869170033915787.csv', '869170033929473.csv', '869170033928152.csv', '869170034777863.csv', '869170034778101.csv', '8691700348085280.csv', '869170034808544.csv', '869170034808676.csv', '869170034808684.csv', '869170034808718.csv', '869170034808726.csv', '869170034808700.csv', '8691700348087260.csv', '869170034808734.csv', '869170034808742.csv', '869170034808759.csv', '869170034808767.csv', '869170034808783.csv', '869170034808981.csv', '869170034808817.csv', '8691700348089810.csv', '869170034809062.csv', '869170034810797.csv', '869170034811282.csv', '8691700348108390.csv', '8691700352467020.csv', '869170035231852.csv', '8691700352467280.csv', '8691700352467440.csv', '8691700352468680.csv', '8691700352479160.csv', '869170035249011.csv', '869170035251298.csv', '8691700352538230.csv', '8691700352538720.csv', '8691700352538800.csv', '8691700352539060.csv', '8691700352618260.csv', '8691700352618750.csv', '8691700352618830.csv', '8691700352619170.csv', '8691700352619250.csv', '8691700352619740.csv', '8691700352619820.csv', '869170035261982.csv', '9036217273.csv', '9031229950.csv', '8691700352649860.csv', '92037472612.csv', '92036031765.csv', 'peercore-F.csv', 'peercore-G.csv', 'peercore-H.csv', 'testin1.csv', 'testin2.csv', 'testin3.csv', 'testin4.csv', 'testin5.csv', 'testin6.csv', 'testing.csv', 'testing2210.csv', 'testing_cont.csv']

# %%
needed_values = ["B", "IT", "LIA1", "H", "IRO", "T", "ST", "SS"]

for id_csv_file in csv_files:
  id = Path(id_csv_file).stem
  # print("id ", id)
  save_data = {}
  fault_detected = False
  pivot_df = pd.read_csv("/content/drive/MyDrive/Senzmate/RCA/Analyzed_dataframes_for_each_devices/{}".format(id_csv_file),  on_bad_lines='skip')
  for column in pivot_df.columns:
    if column in needed_values:
      save_data[column] = {}
      grp_by_data_miss_flag = pivot_df.groupby('{}_data_miss_flag'.format(column))
      if 1 in grp_by_data_miss_flag.groups:
        miss_data_df = grp_by_data_miss_flag.get_group(1)
        save_data[column]["miss_data_error"] = list(miss_data_df['time'])
        fault_detected = True

      grp_by_data_high_volumn_flag = pivot_df.groupby('{}_high_volumn_flag'.format(column))
      if 1 in grp_by_data_high_volumn_flag.groups:
        high_volumn_data_df = grp_by_data_high_volumn_flag.get_group(1)
        save_data[column]["high_volumn_error"] = list(high_volumn_data_df['time'])
        fault_detected = True
      
      grp_by_outlier_flag = pivot_df.groupby('{}_outlier_flag'.format(column))
      if 1 in grp_by_outlier_flag.groups:
        outlier_data_df = grp_by_outlier_flag.get_group(1)
        save_data[column]["outlier_data_error"] = list(outlier_data_df['time'])
        fault_detected = True
  
  if fault_detected:
    with open("/content/drive/MyDrive/Senzmate/RCA/Analyzed_dataframes_for_each_devices/{}.json".format(id), "w") as outfile:
      json.dump(save_data, outfile)
